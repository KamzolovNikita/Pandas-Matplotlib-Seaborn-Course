# %% [markdown]
# # Создание структуры Subplot'ов

# %% [markdown]
# ### Условие

# %% [markdown]
# Необходимо написать тело функции solve, которая формирует график необходимой структуры.
#
# Требования к графику:
# 1. Создан объект данных типа matplotlib.pyplot.Figure с размерами 10x9 единиц (height = 9, width = 10)
# 2. C помощью вызова метода add_gridspec и вызовов метода add_subplot над созданным объектом составлена необходимая структура расположения подграфиков (изображена на рисунке)
#
# В качестве возвращаемого значения необходимо передать, созданный объект данных типа matplotlib.pyplot.Figure.
#
# **Gridscpec должен быть задан только один**
#
# ![image.png](attachment:image.png)
#
# *Для вашего удобства уже импортирована библиотека matplotlib.pyplot как plt. Импортировать другие библиотеки запрещено.*
#
# *Для решения этой задачи вам необходимо знать, как работаю методы [pyplot.figure](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html), [Figure.add_gridspec](https://matplotlib.org/stable/api/figure_api.html#matplotlib.figure.Figure.add_gridspec), [Figure.add_subplot](https://matplotlib.org/stable/api/figure_api.html#matplotlib.figure.Figure.add_subplot)*

# %% [markdown]
# # Простые настройки визуализации графиков

# %% [markdown]
# ### Условие

# %% [markdown]
# Необходимо написать тело функции  solve, которая отрисовывает график, удовлетворяющий требованием, указанным ниже.
#
# На вход функции Solve передается:
# 1. Объект типа данных AxesSubplot
# 2. Значения X
# 3. Значения Y
# 4. Цвет в формате строки - "#000000"
# 5. Заголовок
#
# Требования к графику:
# 1. Должен быть построен линейный график по переданным данным
# 2. Ось X должна быть ограничена интервалом [minX, max(100, maxX)]
# 3. Ось Y должна быть ограничена интервалом [minY, max(1000, maxY)]
# 4. Цвет должен совпадать с переданным
# 5. Заголовок графика должен совпадать с переданным в функцию
# 6. Отметки графика по оси абсцисс и оси ординат должны совпадать с переданными значениями
# 8. Оси должны быть подписаны "X" и "Y" для абсциссы и ординаты, соответственно
# 9. Должна быть выведена сетка
#
# **Функция должна выполнять все преобразования над объектом типа данных AxesSubplot, переданном во входных параметрах функции. Только в этом случае автоматическая система сможет проверить Ваше решение.**
#
# *Для вашего удобства уже импортирована библиотека matplotlib.pyplot как plt. Импортировать другие библиотеки запрещено.*
#
# *Для решения этой задачи вам необходимо знать, как работаю методы*
# * [AxesSubplot.set_xlim](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xlim.html)
# * [AxesSubplot.set_ylim](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_ylim.html)
# * [AxesSubplot.set_title](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_title.html)
# * [AxesSubplot.set_xlabel](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xlabel.html)
# * [AxesSubplot.set_ylabel](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_ylabel.html)
# * [AxesSubplot.set_xticks](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xticks.html)
# * [AxesSubplot.set_yticks](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_yticks.html)
# * [AxesSubplot.grid](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.grid.html)
# * [AxesSubplot.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.plot.html)

# %% [markdown]
# # Типы маркеров scatter-plot

# %% [markdown]
# ### Условие

# %% [markdown]
# Соотнесите обозначение маркера и фигуру, которую этот маркер описывает.
#
# Для решения этой задачи вам необходимо знать [обозначения маркеров](https://matplotlib.org/stable/api/markers_api.html).

# %% [markdown]
# ### Решение

# %% [markdown]
# . - Точка
#
# o - Кружок
#
# s - Квадрат
#
# d - Ромб
#
# D - Широкий ромб
#
# x - крестик

# %% [markdown]
# # Построение линейных графиков в Matplotlib

# %% [markdown]
# ### Условие

# %% [markdown]
# Необходимо написать тело функции  solve, которая отрисовывает график, удовлетворяющий требованием, указанным ниже.
#
# На вход функции Solve передается:
# 1. Объект типа данных AxesSubplot
# 2. Список значений X для всех графиков
# 3. Двумерный список вида: [[значения Y 1-го графика], [значения Y 2-го графика], [значения Y 3-го графика]]
# 4. Список вида: ["Цвет 1-го графика в формате строки #000000", "Цвет 2-го графика в формате строки #000000", "Цвет 3-го графика в формате строки #000000"]
# 5. Список вида: ["Лейбл 1-го первого графика", "Лейбл 2-го первого графика", "Лейбл 3-го первого графика"]
# 6. Заголовок
#
# Требования к общему графику:
# 1. На одной плоскости должны быть построены 3 линейных графика
# 2. Оси должны быть подписаны "X" и "Y" для абсциссы и ординаты, соответственно
# 3. Должна быть отображена легенда графика
# 4. Отображен, переданный заголовок графика
#
# Требования к 1-му линейному графику:
# 1. Точки графика должны быть выделены квадратами
# 2. Цвет должен совпадать с переданным
# 3. Лейбл должен совпадать с переданным
# 4. Размер квадрата-маркера должен быть равен 5
# 5. К графику должно быть применено сглаживание
# 6. Толщина линии должна быть 10
#
# Требования к 2-му линейному графику:
# 1. Точки графика должны быть выделены X-образным маркером
# 2. Цвет должен совпадать с переданным
# 3. Лейбл должен совпадать с переданным
# 4. Линия должна быть полупрозрачной (alpha = 0.5)
# 5. Линия должна быть штрих-пунктирной
#
# Требования к 3-му линейному графику:
# 1. Точки графика должны быть выделены широким ромбовидным маркером
# 2. Цвет должен совпадать с переданным
# 3. Лейбл должен совпадать с переданным
# 4. Линия должна быть штриховой (dashed-style)
# 5. Толщина границы маркера должна быть равна 2 и ее цвет должен быть черным ('black')
#
# **Функция должна выполнять все преобразования над объектом типа данных AxesSubplot, переданном во входных параметрах функции. Только в этом случае автоматическая система сможет проверить Ваше решение.**
#
# *Для вашего удобства уже импортирована библиотека matplotlib.pyplot как plt. Импортировать другие библиотеки запрещено.*
#
# *Для решения этой задачи вам необходимо знать, как работаю методы [AxesSubplot.set_xlabel](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xlabel.html), [AxesSubplot.set_ylabel](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_ylabel.html), [AxesSubplot.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.plot.html), [AxesSubplot.legend](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.legend.html)*

# %% [markdown]
# # Ступенчатый график

# %% [markdown]
# ### Условие

# %% [markdown]
# Даны 3 графика. Необходимо соотнести график и функцию, с помощью которой был изображен этот график.
#
# Для решения этой задачи вам необходимо знать, как работает метод [AxesSubplot.step](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.step.html).

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)
#
# ![image.png](attachment:image-3.png)
#
# plt.plot(x, y, where="pre", marker="o")
#
# plt.plot(x, y, where="mid", marker="o")
#
# plt.plot(x, y, where="post", marker="o")

# %% [markdown]
# # Построение линейных графиков в Pandas

# %% [markdown]
# ### Условие

# %% [markdown]
# Необходимо написать тело функции solve, которая отрисовывает график, удовлетворяющий требованием, указанным ниже.
#
# На вход функции Solve передается:
# 1. Объект типа данных AxesSubplot
# 2. Структура данных pd.DataFrame
# 3. Список цветов
#
# Требования к графику:
# 1. Построен набор линейных графиков (отдельный график для каждого столбца, переданного DataFrame)
# 2. Цвет каждого линейного графика соответствует цвету из списка цветов, взятого по порядку следования столбцов(то есть 1-ый цвет из списка цветов соответствует графику, построенному по 1-му столбцу DataFrame и так далее)
#
# *Гарантируется, что список цветов и кол-во столбцов DataFrame совпадают*
#
# **Для работы автоматической проверки, при отрисовке графика необходимо явно указать параметр ax и передать туда объект типа данных AxesSubplot, переданный в функцию solve.**
#
# *Для вашего удобства уже импортирована библиотеки matplotlib.pyplot как plt и pandas как pd. Импортировать другие библиотеки запрещено.*
#
# *Для решения этой задачи вам необходимо знать, как работаю методы [DataFrame.plot.line](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.line.html)*

# %% [markdown]
# # Построение площадных диаграмм в Matplotlib

# %% [markdown]
# ### Условие

# %% [markdown]
# Необходимо написать тело функции solve, которая отрисовывает график, удовлетворяющий требованием, указанным ниже.
#
# На вход функции Solve передается:
# 1. Объект типа данных AxesSubplot
# 2. Список значений X
# 3. Список значений Y
#
# Требования к графику:
# 1. Начерчена площадная диаграмма (залита площадь под графиком)
# 2. Заливка имеет зеленый цвет ('green') и полупрозрачна (alpha = 0.5)
# 3. Границы площадной диаграммы выделены линией
#
# **Для работы автоматической проверки, при отрисовке графика необходимо явно указать параметр ax и передать туда объект типа данных AxesSubplot, переданный в функцию solve.**
#
# *Для вашего удобства уже импортирована библиотека matplotlib.pyplot как plt. Импортировать другие библиотеки запрещено.*
#
# *Для решения этой задачи вам необходимо знать, как работаю методы [AxesSubplot.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.plot.html), [AxesSubplot.fill_between](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.fill_between.html)*
#
# Пример для функции sin(x):
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Построение площадных диаграмм в Matplotlib 2

# %% [markdown]
# ### Условие

# %% [markdown]
# Необходимо написать тело функции solve, которая отрисовывает график, удовлетворяющий требованием, указанным ниже.
#
# На вход функции Solve передается:
# 1. Объект типа данных AxesSubplot
# 2. Список значений X
# 3. Список значений Y для первого графика
# 4. Список значений Y для второго графика
# Необходимо написать тело функции solve, которая отрисовывает график, удовлетворяющий требованием, указанным ниже.
#
# Требования к графику:
# 1. Начерчена площадная диаграмма между двумя графиками, построенными по спискам значений Y, только для x в области (2, 5)
# 2. Границы площадной диаграммы выделены линией
#
# **Для работы автоматической проверки, при отрисовке графика необходимо явно указать параметр ax и передать туда объект типа данных AxesSubplot, переданный в функцию solve.**
#
# *Для вашего удобства уже импортирована библиотека matplotlib.pyplot как plt. Импортировать другие библиотеки запрещено.*
#
# Для решения этой задачи вам необходимо знать, как работаю методы [AxesSubplot.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.plot.html), [AxesSubplot.fill_between](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.fill_between.html)
#
# *Пример для функций sin(x) и cos(x):*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Построение площадной диаграммы в Pandas

# %% [markdown]
# ### Условие

# %% [markdown]
# Даны два графика, которые были начерчены с помощью функции df.plot.area() с разным значением параметра stacked. Соотнесите значение stacked и график.
#
# Для решения этой задачи вам необходимо знать, как работает метод [DataFrame.plot.area()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.area.html).

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)
#
# stacked=True
#
# stacked=False

# %% [markdown]
# # Построение столбчатой диаграммы в Matplotlib

# %% [markdown]
# ### Условие

# %% [markdown]
# Необходимо написать тело функции solve, которая отрисовывает график, удовлетворяющий требованием, указанным ниже.
#
# На вход функции Solve передается:
# 1. Объект типа данных AxesSubplot
# 2. Список значений X
# 3. Длина интервала - целочисленное значение
# 4. Список цветов столбцов в формате строк (например, ['red','blue','green'])
#
# Требования к графику:
# 1. Начерчена столбчатая диаграмма.
# 2. Высоты столбцов должны быть посчитаны следующим образом: исходный список значений X разбивается на интервалы длины, которая была передана в функцию. Считается количество значений x, которое попало в каждый интервал (левая граница интервала включается, правая - нет), посчитанное значение используется в качестве высоты столбца.
# 3. Средние значения x интервалов, посчитанных на предыдущем шаге должны быть центрами столбцов в итоговом графике, эти значения должны быть отмечены на оси X.
# 4. Ширина столбцов должна быть равна 0.5.
# 5. Цвета столбцов окрашены в цвета из переданного списка, важно сохранить порядок.
#
# **Для работы автоматической проверки, при отрисовке графика необходимо явно указать параметр ax и передать туда объект типа данных AxesSubplot, переданный в функцию solve.**
#
# *Значения в списке X отсортированы по возрастанию. Гарантируется, что в списке цветов количество элементов больше или равно количеству интервалов после разбиения.*
#
# *Для вашего удобства уже импортирована библиотеки matplotlib.pyplot как plt, numpy как np и pandas как pd. Импортировать другие библиотеки запрещено.*
#
# *Для решения этой задачи вам необходимо знать, как работаю методы [AxesSubplot.bar](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.bar.html), [AxesSubplot.set_xticks](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xticks.html)*

# %% [markdown]
# # Построение столбчатой диаграммы в Matplotlib (усложненное)

# %% [markdown]
# ### Условие

# %% [markdown]
# Необходимо написать тело функции solve, которая отрисовывает график, удовлетворяющий требованием, указанным ниже.
#
# На вход функции Solve передается:
# 1. Объект типа данных AxesSubplot
# 2. Список меток - центров столбцов диаграммы по X.
# 3. Список высот для левых столбцов.
# 4. Список высот для правых столбцов.
#
# Требования к графику:
# 1. Начерчена столбчатая диаграмма, как в примере.
# 2. Левые столбцы имеют высоты, соответствующие списку высот левых столбцов, переданному в функцию.
# 3. Правые столбцы имеют высоты, соответствующие списку высот правых столбцов, переданному в функцию.
# 4. Ширина столбцов должна быть равна 0.4.
# 5. Левые столбцы окрашены в оранжевый цвет ('orange'), правые - в синий ('blue')
# 6. Метки по оси X должны совпадать с переданным списком меток - центров столбцов
#
# **Для работы автоматической проверки, при отрисовке графика необходимо явно указать параметр ax и передать туда объект типа данных AxesSubplot, переданный в функцию solve.**
#
# *Размеры всех списков, переданных в функцию совпадают*
#
# *Для вашего удобства уже импортирована библиотеки matplotlib.pyplot как plt. Импортировать другие библиотеки запрещено.*
#
# *Для решения этой задачи вам необходимо знать, как работаю методы [AxesSubplot.bar](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.bar.html), [AxesSubplot.set_xticks](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xticks.html)*
#
# Пример графика:
# ![image.png](attachment:image.png)

# %% [markdown]
# # Построение накопленной линейчатой диаграммы в Matplotlib

# %% [markdown]
# ### Условие

# %% [markdown]
# Необходимо написать тело функции solve, которая отрисовывает график, удовлетворяющий требованием, указанным ниже.
#
# На вход функции Solve передается:
# 1. Объект типа данных AxesSubplot
# 2. Список меток - центров столбцов диаграммы по Y.
# 3. Список высот для левых столбцов
# 4. Список высот для правых столбцов.
#
# Требования к графику:
# 1. Начерчена линейчатая диаграмма, как в примере.
# 2. Левые столбцы имеют высоты, соответствующие списку высот левых столбцов, переданному в функцию.
# 3. Правые столбцы имеют высоты, соответствующие списку высот правых столбцов, переданному в функцию, но также должны иметь накопительный эффект с правыми столбцами (то есть если левый столбец в списке имеет высоту 2, а правый в списке 4, то их суммарная длина должна быть 6, но правая часть занимает только 4)
# 4. Ширина столбцов должна быть 0.7.
# 5. Левые столбцы окрашены в оранжевый цвет ('orange'), правые - в синий ('blue')
# 6. Метки по оси Y должны совпадать с переданным списком меток - центров столбцов
#
# **Для работы автоматической проверки, при отрисовке графика необходимо явно указать параметр ax и передать туда объект типа данных AxesSubplot, переданный в функцию solve.**
#
# *Размеры всех списков, переданных в функцию совпадают*
#
# *Для вашего удобства уже импортирована библиотеки matplotlib.pyplot как plt, numpy как np и pandas как pd. Импортировать другие библиотеки запрещено.*
#
# *Для решения этой задачи вам необходимо знать, как работаю методы [AxesSubplot.barh](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.barh.html), [AxesSubplot.set_yticks](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_yticks.html)*
#
# *Пример графика:*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Построение круговой диаграммы в Matplotlib

# %% [markdown]
# ### Условие

# %% [markdown]
# Необходимо написать тело функции solve, которая отрисовывает график, удовлетворяющий требованием, указанным ниже.
#
# На вход функции Solve передается:
# 1. Объект типа данных AxesSubplot
# 2. Список значений для отрисовки частей круговой диаграммы
# 3. Список меток для частей круговой диаграммы (соответствие с значениями по расположению в списке)
# 4. Список цветов для отрисовки частей круговой диаграммы (аналогично, соответствие с значениями по расположению в списке)
#
# Требования к графику:
# 1. Начерчена круговая диаграмма по переданному списку значений.
# 2. У каждой части круговой диаграммы стоит подпись из списка меток.
# 3. Каждая часть круговой диаграммы окрашена в свой цвет из списка цветов.
# 4. Каждая часть круговой диаграммы имеет по краям линию шириной равной 2 любого цвета.
# 5. Стартовый угол круговой диаграммы равен 90 градусов (то есть присутствует смещение).
# 6. Текст меток должен быть окрашен в оранжевый ('orange').
#
# **Для работы автоматической проверки, при отрисовке графика необходимо явно указать параметр ax и передать туда объект типа данных AxesSubplot, переданный в функцию solve.**
#
# *Размеры всех списков, переданных в функцию совпадают.*
#
# *Для вашего удобства уже импортирована библиотеки matplotlib.pyplot как plt. Импортировать другие библиотеки запрещено.*
#
# *Для решения этой задачи вам необходимо знать, как работаю методы [AxesSubplot.pie](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html).*

# %% [markdown]
# # Построение столбчатой и линейчатой диаграммы в Pandas

# %% [markdown]
# ### Условие

# %% [markdown]
# DataFrame имеет следующую структуру:
#
# ![image.png](attachment:image.png)
#
# Соотнесите график и вызов метода, с помощью которого этот график был построен.
#
# *Для решения этой задачи вам необходимо знать, как работаю методы [DataFrame.plot.bar](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html) и [DataFrame.plot.barh](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.barh.html).*

# %% [markdown]
# ### Решение

# %% [markdown]
# ![image.png](attachment:image-3.png)
#
# ![image.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-4.png)
#
# ![image.png](attachment:image-5.png)
#
# df.plot.bar(rot=0, stacked = True)
#
# df.plot.bar(rot=0)
#
# df.plot.bar(rot=0, subplots=True)
#
# df.plot.barh(rot=0, stacked = True)
#
# df.plot.barh(rot=0, subplots=True)

# %% [markdown]
# # Основные методы Seaborn

# %% [markdown]
# ### Условие

# %% [markdown]
# Соотнесите метод Seaborn и график, который она рисует.
#
# *Для решения этой задачи вам необходимо знать, как работаю методы [Seaborn.lineplot](https://seaborn.pydata.org/generated/seaborn.lineplot.html), [Seaborn.scatterplot](https://seaborn.pydata.org/generated/seaborn.scatterplot.html), [Seaborn.barplot](https://seaborn.pydata.org/generated/seaborn.barplot.html), [Seaborn.heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html)*

# %% [markdown]
# sns.lineplot
#
# sns.scatterplot
#
# sns.barplot
#
# sns.heatmap
#
# Точечный график
#
# Линейный график
#
# Столбчатая диаграмма
#
# Тепловая карта

# %% [markdown]
# # Метод Seaborn.pairplot

# %% [markdown]
# ### Условие

# %% [markdown]
# Соотнесите график и вызов метода Seabor.pairplot, с помощью которого он был отрисован.
#
# *Для решения этой задачи вам необходимо знать, как работаю методы [Seaborn.pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html).*

# %% [markdown]
# ### Решение

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)
#
# ![image.png](attachment:image-3.png)
#
# ![image.png](attachment:image-4.png)
#
# sns.pairplot(penguins)
#
# sns.pairplot(penguins, hue='species')
#
# sns.pairplot(penguins, kind="hist")
#
# sns.pairplot(penguins, kind="kde")

# %% [markdown]
# # Построение тепловой карты в Seaborn

# %% [markdown]
# ### Условие

# %% [markdown]
# Необходимо написать тело функции solve, которая отрисовывает график, удовлетворяющий требованием, указанным ниже.
#
# На вход функции Solve передается:
# 1. Объект типа данных AxesSubplot
# 2. Объект типа данных DataFrame
#
# Требования к графику:
# 1. Построена тепловая карта с помощью библиотеки Seaborn
# 2. Аннотируйте каждую ячейку тепловой карты, соответствующим ей значением
# 3. Добавьте расстояние между ячейками тепловой карты, размером 0.5
#
# **Для работы автоматической проверки, при отрисовке графика необходимо явно указать параметр ax и передать туда объект типа данных AxesSubplot, переданный в функцию solve.**
#
# *Для вашего удобства уже импортирована библиотеки matplotlib.pyplot как plt, numpy как np, pandas как pd и seaborn as sns . Импортировать другие библиотеки запрещено.*
#
# *Для решения этой задачи вам необходимо знать, как работаю методы [Seaborn.heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html)*
